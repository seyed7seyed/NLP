# %% [markdown]
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> NLP <Br><Br>Read & Pre-Process

# %% [markdown]
# #####
# <span style="font-family:Arial; font-weight:Bold; font-size:1.8em; color:#00b3e5;"> Reading PDF

# %%
import PyPDF2

# %%
data   = open('Intro_to_Python_Part_1.pdf','rb')
reader = PyPDF2.PdfReader(data)

# %%
len(reader.pages)  # number of pages
# Out:
# 67

# %%
page = reader.pages[0]
print( page.extract_text() )
# Out:
# Introduction to Python
# Part 1
# Brian Gregor
# Research Computing Services
# Information Services & Technology

# %%
data.close()

# %% [markdown]
# #####
# <span style="font-family:Arial; font-weight:Bold; font-size:1.8em; color:#00b3e5;"> Reading Text

# %%
data = open('NLP_Text_Example.txt','r')
print( data.read() )
# Out:
# Consulting Focus:
#  Bioinformatics
#  Data Analysis / Statistics
#  Molecular modeling
#  Geographic Information Systems
#  Scientific / Engineering Simulation
#  Visualization

# %% [markdown]
# #####
# <span style="font-family:Arial; font-weight:Bold; font-size:1.8em; color:#00b3e5;"> Reading CSV

# %%
import numpy  as np
import pandas as pd

# %%
data = pd.read_csv('NLP_CSV_Example.csv')
data.head()
# Out:
#    label                             sentence
# 0      0               Hi I heard about Spark
# 1      0   I wish Java could use case classes
# 2      0  Logistic Regression models are neat

# %% [markdown]
# #####
# <span style="font-family:Arial; font-weight:Bold; font-size:2.3em; color:#00b3e5;"> PreProcessing

# %% [markdown]
# ![Photo-2.png](attachment:Photo-2.png)

# %% [markdown]
# ![Photo.png](attachment:Photo.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #####

# %% [markdown]
# #####
